# %% [markdown]
# # How to use logging
# ### first we have to import a this file whit his config log file in the work space

# %%
#This tool is to record the action that happened in the program, we can record information at different levels, save in different locations, send this logs in mails etc.
#When the program increases in size, the logs gain importance to know where the problem is.
import matplotlib.pyplot as plt
import traceback

# %% [markdown]
# ### import the module and the Library traceback and write the sencence in the workspace

# %%
# The name "logger" is a standardized name, you can use whatever you want.
# "logger" was our object that internalized all the logging functions.
# You write it followed by the level of information you want to record and its description,
# this sentence will go below the part of the code you want to record. Example

# %%
from myloggers import mylogger

logger=mylogger()
print("this function well")
logger.info("this function well")
logger.critical("this function well")
# Out:
# this function well
# 2020-11-09 19:54:21,550 : myloggers : <ipython-input-3-690a6b71afcd>:<module> : INFO : this function well
# 2020-11-09 19:54:21,557 : myloggers : <ipython-input-3-690a6b71afcd>:<module> : CRITICAL : this function well

# %%
# The record will be displayed on the console, with all the information we request in the format.
# And the record is going to be saved in a file that we specified earlier in the config log.

# %%
#We could set the level of information we could have to save or display, we can change that in the file config, 
#this was in a environment of variables.
#I going to teach how to change in the config log.

# %%
#first we open the file "logging.conf"
#will be seen someting like that (with out the commentary, 
#these was used to teach how to use the relevant variables and parameters of the config log).
#before implement this jupyter file change the path of all images
img=plt.imread(r"C:\Users\patoPC\Desktop\logging\loggingconf.png")
plt.figure(figsize=(40,40))
plt.imshow(img)

# %% [markdown]
# ## Separing in parts

# %%
img=plt.imread(r"C:\Users\patoPC\Desktop\logging\logg1.png")
plt.figure(figsize=(40,40))
plt.imshow(img)
#this first part is for dessign the main componennt handlers and logger.
#We can change the name of the keys that we will use in the next parts.

# %%
img=plt.imread(r"C:\Users\patoPC\Desktop\logging\logg2.png")
plt.figure(figsize=(40,40))
plt.imshow(img)
#This seccond part defines the handlers, the loggers who we are going to personalize and what we save,show or send

# %%
img=plt.imread(r"C:\Users\patoPC\Desktop\logging\logg3.png")
plt.figure(figsize=(40,20))
plt.imshow(img)
#And this last part we defines the formatting we want to aply of any handler, what we want to show in the handlers

# %%
# First we going to sets the level of record in info, and the display console in warning.
#We going at our log.config and change this parameters



img=plt.imread(r"C:\Users\patoPC\Desktop\logging\setle.png")
plt.figure(figsize=(40,20))
plt.imshow(img)

#Try to change the level in logging.conf the below image:

# %%
img=plt.imread(r"C:\Users\patoPC\Desktop\logging\path.png")
plt.figure(figsize=(40,20))
plt.imshow(img)

# you can change the path of the log file in logging.conf as shown in the following image:

# %%
img=plt.imread(r"C:\Users\patoPC\Desktop\logging\format.png")
plt.figure(figsize=(40,20))
plt.imshow(img)

# you can change the format of the log file or display in console in logging.conf as shown in the following image:

# %%
#first i clean the python log 
f = open("python.log", "w")
f.write("")
f.close()

"""In this part I restart the terminal because I have an 
error that does not allow me to show or dysplay the logger or 
continue with the practical example"""
exit()

# %%
# In a workspace you only have to attach the files myloggers.py and logging.conf
#the forlder to the workspace and write the first 3 lines of code below
# As you work, you will write your own registration codes with the object logger
# as in the first example.
import traceback

from myloggers import mylogger
logger=mylogger()
#Well now we are going to prove the logger with a own class with many log for register and show
#these are as examples of the use of logs in the real life

class testfunction:
       
    logger.debug('The program is function well')
    print("====================================")
    print(" ")
    print("Introduce any ID, the program will be generated a password for you this time ")
    print("")
    Users = input("User ID: ")
    print("====================================")
    print("")
    print("Your passwordtest is ({}{}) try with that ".format(Users[-1:0:-1], Users[0]))
    print("")
    print("====================================")
    password = input("Introduce your password :")
    testpasword = "{}{}".format(Users[-1:0:-1], Users[0])
    if password != testpasword:
        logger.critical("The password is incorrect, you not have access to the program, the program will be closed")
        exit()
    logger.info("everything is fine")
    def __init__(self, x, y):
        try:
            self.result=x/y

        except :
            logger.error("The log of the error are %s", traceback.format_exc())
        
    def adde(self,x,y):
        try:
            adde=x+y
        except:
            logger.error("The program cant add this values")
        try:
            return adde,  logger.info('The program is okay and the result are {}'.format(adde))
        except:
            logger.error("The variables input cannot be added")
    def doingyouremail(self):
        name=input("Introduce your name, and last name separed by a space: ")
        FirstName=name.split(" ")[0]
        try:
            LastName=name.split(" ")[1]
        except:
            logger.critical("The user didn't introduce at least 2 words, the program cannot will be doing his email")
        try:    
            if len(FirstName)+len(LastName)>=20:
                logger.warning("The name is too large your email will be difficult to memorize")
            email="{}.{}@mycompany.com".format(FirstName, LastName)
            logger.info("dear user your credencials are/ name: {}, last: {}, email:  {} /".format(FirstName, LastName,email))
        except: 
            logger.info("Please introduce your first name and last name")
        
        
#if you fail the password the program will kill/restart the terminal.
#if you not are in jupyter the log be will record in the python.log as critical.
# Out:
# 2020-11-09 19:55:15,873 : myloggers : <ipython-input-1-09c580bc8775>:testfunction : DEBUG : The program is function well
# ...
#
# Introduce any ID, the program will be generated a password for you this time
#
# User ID: 456
# ...
#
# Your passwordtest is (654) try with that
#
# ...
# Introduce your password :654
# 2020-11-09 19:55:21,232 : myloggers : <ipython-input-1-09c580bc8775>:testfunction : INFO : everything is fine

# %%
# How can we see that any loggregister was displayed because we changed the level. We keep probing with another test
#the first function in class __init__ (it is a constructor) automatically divides the first parameter to the second, if the second parameter is equal to zero
#function returns a screen and logs the error.
pato1=testfunction(2, 0)
# Out:
# 2020-11-09 19:55:22,947 : myloggers : <ipython-input-1-09c580bc8775>:__init__ : ERROR : The log of the error are Traceback (most recent call last):
#   File "<ipython-input-1-09c580bc8775>", line 32, in __init__
#     self.result=x/y
# ZeroDivisionError: division by zero

# %%
#how we can see the logging catch the error in the function divide for cero
#now prove not divided by zero
pato1=testfunction(2, 1)

# %%
#nothing return.
#test another adde is a function to adde the first parameter at the second. but if the first or second parameter is not a number
#what going to do?
pato1.adde("a",1)
# Out:
# 2020-11-09 19:55:25,948 : myloggers : <ipython-input-1-09c580bc8775>:adde : ERROR : The program cant add this values
# 2020-11-09 19:55:25,949 : myloggers : <ipython-input-1-09c580bc8775>:adde : ERROR : The variables input cannot be added

# %%
# How can we see the errors on screen 2. and record the same error 2.
# other test: the function that performs your email requests 2 words for (first and last name to do your email).
# But if the first and last names are too large, the program will warn me. And if the input word is not 2, the program will fail.
# let's try (first try: write a first and last name),

pato1.doingyouremail()
# Out:
# Introduce your name, and last name separed by a space:

# %%
#second try:write a only word
pato1.doingyouremail()
# Out:
# Introduce your name, and last name separed by a space: pat
# 2020-11-09 19:56:05,704 : myloggers : <ipython-input-1-09c580bc8775>:doingyouremail : CRITICAL : The user didn't introduce at least 2 words, the program cannot will be doing his email
# 2020-11-09 19:56:05,705 : myloggers : <ipython-input-1-09c580bc8775>:doingyouremail : INFO : Please introduce your first name and last name

# %%
#3rd try: write one name and one last name with more of 20 characters between them
pato1.doingyouremail()
# Out:
# Introduce your name, and last name separed by a space: patricio pereytra
# 2020-11-09 19:55:49,656 : myloggers : <ipython-input-1-09c580bc8775>:doingyouremail : INFO : dear user your credencials are/ name: patricio, last: pereytra, email:  patricio.pereytra@mycompany.com /

# %%
#at last we could see the register our log
filelog = open("python.log", "r") 
content = filelog.read()
print(content)
# Out:
# 2020-11-09 19:55:15,873 : myloggers : <ipython-input-1-09c580bc8775>:testfunction : DEBUG : The program is function well
# 2020-11-09 19:55:21,232 : myloggers : <ipython-input-1-09c580bc8775>:testfunction : INFO : everything is fine
# 2020-11-09 19:55:22,947 : myloggers : <ipython-input-1-09c580bc8775>:__init__ : ERROR : The log of the error are Traceback (most recent call last):
#   File "<ipython-input-1-09c580bc8775>", line 32, in __init__
#     self.result=x/y
# ZeroDivisionError: division by zero
#
# 2020-11-09 19:55:25,948 : myloggers : <ipython-input-1-09c580bc8775>:adde : ERROR : The program cant add this values
# 2020-11-09 19:55:25,949 : myloggers : <ipython-input-1-09c580bc8775>:adde : ERROR : The variables input cannot be added
# 2020-11-09 19:55:49,656 : myloggers : <ipython-input-1-09c580bc8775>:doingyouremail : INFO : dear user your credencials are/ name: patricio, last: pereytra, email:  patricio.pereytra@mycompany.com /
# ...
